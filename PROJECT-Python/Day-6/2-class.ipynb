# %%
# class
# blueprint used to create objects with similar attributes, methods and behaviour
# example: 
# class : college, car, student
# objects : college_name, (toyota, bmw), (ram, sita)
class Student:
    def  __init__(self,name,age,marks):
        self.name=name
        self.age=age
        self.marks=marks
    
    def show(self):
        print(self.name,"\t",self.age,"\t",self.marks)
        
s1=Student("Kimmich",28,50.12)
s2=Student("Vinicius",25,99.22)
s1.show()
s2.show()
# Out:
# Kimmich 	 28 	 50.12
# Vinicius 	 25 	 99.22

# %%
# __init__ : constructor that runs automatically when object is created
    # when to not use init? 
    #       1. no initial data needed
            # class Hello:
            #     def greet(self):
            #       print("hi")
            
    #       2. temporary results
    
    #       3. static value
            # def greet(self):
            #     print("hello")
# Student.__init__(s1,"Kimmich",28,50.12) : python does internally
# self : refers to current object of class being called
    # when to not use self? 
    #       1. local variables
            # def add(self,a,b):
            #     result=a+b
            #     print(result)
            # add(2,3)
            
    #       2. temporary results
    
    #       3. static value
            # def greet(self):
            #     print("hello")

# Advantage:
#     reusability
#     keeps data organized
#     add more features
#     create unlimited objects

# %%
class Student:
    def __init__(self,name,age,phone):
        self.name=name
        self.age=age
        self.phone=phone
    
    def display(self):
        print(self.name,"\t",self.age,"\t",self.phone)

name=input("Enter student name : ")
age=int(input("Enter age : "))
phone=input("Enter phone number : ")

s=Student(name,age,phone)

print("\nStudent details : ")

s.display()
# Out:
# Student details :
# bale 	 14 	 11211

# %%
# __str__ method:
    # without str : shows  memory location  of object since how to display isnt defined
class Student:
    def __init__(self,name,age,gender):
        self.name=name
        self.age=age
        self.gender=gender
    
    def __str__(self):
        return f"Name : {self.name}, Age : {self.age}, Gender : {self.gender}"
    
a=Student("Benzema",15,"M")
print(a)
# Out:
# Name : Benzema, Age : 15, Gender : M

# %%
class Student:
    def  __init__(self,name,age,marks):
        self.name=name
        self.age=age
        self.marks=marks
    
    def show(self):
        print(f"Name : {self.name}, Age : {self.age}")
        
s1=Student("Kimmich",28,50.12)
s2=Student("Vinicius",25,99.22)
s1.show()
s2.show()
# Out:
# Name : Kimmich, Age : 28
# Name : Vinicius, Age : 25

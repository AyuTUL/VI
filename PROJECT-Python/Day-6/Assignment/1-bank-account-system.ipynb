# %%
# bank account system
# create program to manage bank account
# attributes:
#     account holder Name
#     type of account
#     balance
# program should:
#     create multiple accounts
#     deposit money
#     withdraw money
#     display account details  
class Account:
    def __init__(self,holder_name,type,balance):
        self.holder_name=holder_name
        self.type=type
        self.balance=balance
    
    def deposit(self,amount):
        balance=balance+amount
    
    def withdraw(self,amount):
        balance=balance-amount
        
    def display(self):
        print(f"Account Details :\nAccount Holder : {self.holder_name}\nType of Account : {self.type}\nBalance : Rs. {self.balance}")
        
table=list()

print("---Bank Account Management System---\n1. Create Account\n2. Deposit\n3. Withdraw\n4. View Account Details")
choice=int(input("Enter your choice : "))

print("Enter account details : ")
for i in range(n):
    name=input("Enter account holder's name : ")
    type=input("Enter type of account : ")
    balance=float(input("Enter balance : "))
    
    a=Account(name,type,balance)
    table.append(a)

print("Acc")
# Out:
#   Cell In[1], line 29
#     table=
#           ^
# SyntaxError: invalid syntax

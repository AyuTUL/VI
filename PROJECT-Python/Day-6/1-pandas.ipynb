# %%
import pandas as pd
df=pd.read_csv("pokemon.csv")

# %%
print(df.loc[1:3])
# Out:
#          Name  Type1   Type2   Evolution
# 1     ivysaur  Grass  Poison    venusaur
# 2    venusaur  Grass  Poison         NaN
# 3  charmander   Fire     NaN  charmeleon

# %%
print(df.iloc[3:10])
# Out:
#          Name  Type1   Type2   Evolution
# 3  charmander   Fire     NaN  charmeleon
# 4  charmeleon   Fire     NaN   charizard
# 5   charizard   Fire  Flying         NaN
# 6    squirtle  Water     NaN   wartortle
# 7   wartortle  Water     NaN   blastoise
# 8   blastoise  Water     NaN         NaN
# 9    caterpie    Bug     NaN     metapod

# %%
df['Name']=="Dragapult"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 804    False
# 805    False
# 806    False
# 807    False
# 808    False
# Name: Name, Length: 809, dtype: bool

# %%
df['Name']=="venusaur"
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 804    False
# 805    False
# 806    False
# 807    False
# 808    False
# Name: Name, Length: 809, dtype: bool

# %%
df[df['Type2']=="Fighting"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_43552\366423933.py in ?()
# ----> 1 df[df['Type2']=="Fighting"] and df[df['Type1']=="Fighting"]
#
# e:\Ayu\Python\Lib\site-packages\pandas\core\generic.py in ?(self)
#    1499     @final
#    1500     def __bool__(self) -> NoReturn:
# -> 1501         raise ValueError(
#    1502             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1503             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1504         )
#
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

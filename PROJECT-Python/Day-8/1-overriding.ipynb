# %%
# overriding : parent has method, child inherits it, child changes same method
class Animal:
    def sound(self):
        print("Animal makes sound")

class Dog(Animal):
    def sound(self):
        print("Dog barks")

a=Animal()
b=Dog()

a.sound()
b.sound()
# Out:
# Animal makes sound
# Dog barks

# %%
# using super() with overriding
class Person:
    def show(self):
        print("I am person")

class Student(Person):
    def show(self):
        Person().show()
        print("I am student")

s=Student()
s.show()
# Out:
# I am person
# I am student

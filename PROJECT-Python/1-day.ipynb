# %%
print('hello world')
# Out:
# hello world

# %%
a="hello"
c=22
d=a+str(c)
print(d)
# Out:
# hello22

# %%
a="hello"
c=22
d=a+c
print(d)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 a="hello"
#       2 c=22
# ----> 3 d=a+c
#       4 print(d)
#
# TypeError: can only concatenate str (not "int") to str

# %%
    # variable
    a=12
    print(a)
# Out:
# 12

# %%
a=20 #integer
b=69.69 #float
c=False #boolean
d='hello word' #string
print(a,b,c,d)
# Out:
# 20 69.69 False hello word

# %%
print(type(d))
# Out:
# <class 'str'>

# %%
# mathematics
a=2
b=5
p=a*b
print(p)
# Out:
# 10

# %%
c="hello\nhow you"
print(c)
# Out:
# hello
# how you

# %%
z="hello\n"
print(z*9)
# Out:
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello

# %%
# interest
p=int(input("Enter the principal amount :"))
t=float(input("Enter the time in years :"))
r=float(input("Enter the rate of interest :"))
i=(p*T*r)/100
print("Simple Interest = ",i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 5
#       3 t=float(input("Enter the time in years :"))
#       4 r=float(input("Enter the rate of interest :"))
# ----> 5 i=(p*T*r)/100
#       6 print("Simple Interest = ",i)
#
# NameError: name 'T' is not defined

# %%
# interest
p=int(input("Enter the principal amount :"))
t=float(input("Enter the time in years :"))
r=float(input("Enter the rate of interest :"))
i=(p*t*r)/100
print("Simple Interest = ",i)
# Out:
# Simple Interest =  1250.0

# %%
name=input("Enter your name : ")
add=input("Enter your address : ")
info="hello world I am "+name+"."+" I am from "+add+"."
print(info)
# Out:
# hello world I am black panther. I am from wakanda.

# %%
# input marks and calculate percentage
sub1=float(input("Enter the marks of subject 1 : "))
sub2=float(input("Enter the marks of subject 2 : "))
sub3=float(input("Enter the marks of subject 3 : "))
sub4=float(input("Enter the marks of subject 4 : "))
sub5=float(input("Enter the marks of subject 5 : "))
total=sub1+sub2+sub3+sub4+sub5
per=total/5
print("Percentage = ",per,"%")
# Out:
# Percentage =  12.4 %

# %%
# if else
# if <condition>
    # <operation>
# elif <condition>
    # <operation>
# else
    # <operation>
age=int(input("Enter your age : "))
if age>18:
    print("You can vote")
elif age==18:
    print("You can vote after 1 year")
else:
    print("You cannot vote")
# Out:
# You can vote after 1 year

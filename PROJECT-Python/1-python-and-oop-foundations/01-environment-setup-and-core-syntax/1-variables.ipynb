# %%
print('hello world')
# Out:
# hello world

# %% [markdown]
# ## Variable

# %%
a=12
print(a)
# Out:
# 12

# %%
a=input("Enter value : ")
b=input("Enter value : ")
c=a+b
print(c)
# Out:
# 14-12

# %%
c="hello\nhow you"
print(c)
# Out:
# hello
# how you

# %%
a="""Hello
What's up
im fine"""
print(a)
# Out:
# Hello
# What's up
# im fine

# %%
z="hello\n"
print(z*9)
# Out:
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello

# %%
name=input("Enter your name : ")
add=input("Enter your address : ")
info="hello world I am "+name+"."+" I am from "+add+"."
print(info)
# Out:
# hello world I am Haaland. I am from MCI.

# %%
a=10
b=complex(a,7)
print(b)
# Out:
# (10+7j)

# %% [markdown]
# List

# %%
info=["python","java","c","java"]
name="java"
if name in info:
    print("yes ",name," is in list")
    print(info.count(name))
else:
    print("no",name," is not in list")

# %%
info="Ram Shyma Hari Sita Gita"
c=info.split()
print(c)

# %%
l=list()
a=["java","pearl","python","c#"]
print(a[0])
print(a[0:3])
print(len(a))
print(a*2)

for i in range(len(a)):
    print(a[i])
    
for i in a:
    print(i)
# Out:
# java
# ['java', 'pearl', 'python']
# 4
# ['java', 'pearl', 'python', 'c#', 'java', 'pearl', 'python', 'c#']
# java
# java
# pearl
# python
# c#
# pearl
# java
# pearl
# python
# c#
# python
# java
# pearl
# python
# c#
# c#
# java
# pearl
# python
# c#

# %%
# append
a=list()
a.append("metronome")
a.append("world")
a
# Out:
# ['metronome', 'world']

# %%
# insert
a=["batman","superman","flash"]
a.insert(2,"wonder woman")
a
# Out:
# ['batman', 'superman', 'wonder woman', 'flash']

# %%
# extend
a=["cap","spidey","cyclops"]
b=[1,2,3,4,5,6]
a.extend(b)
a
# Out:
# ['cap', 'spidey', 'cyclops', 1, 2, 3, 4, 5, 6]

# %%
num=[5,3,-34,0,221]
print("Max = ",max(num))
print("Min = ",min(num))
print("Sum = ",sum(num))
num.reverse()
print("Reverse = ",num)
# Out:
# Max =  221
# Min =  -34
# Sum =  195
# Reverse =  [221, 0, -34, 3, 5]

# %%
# update
a=["bale","benzema","cristiano"]
a[0]="isco"
a
# Out:
# ['isco', 'benzema', 'cristiano']

# %%
# update & add
a=["bale","benzema","cristiano"]
a[0:2]=['vinicius','mbappe']
a
# Out:
# ['vinicius', 'mbappe', 'cristiano']

# %%
# delete
a=["alli","kane","son","erikson"]
del a[1:3] #1 include 3 exclude
a
# Out:
# ['alli', 'kane', 'son', 'erikson']

# %%
#remove
a=[1,4,2,1]
a.remove(1)
a
# Out:
# [4, 2, 1]

# %%
# pop
a=[5,3,2,4]
b=a.pop()
print(b)
print(a)
a.clear()
a
# Out:
# 4
# [5, 3, 2]
# []

# %%
# nested list
a = [["dd", 21, "das"],
     331,
     "44",
     "prick"]
print(a[0])
print(a[1])
print(a[0][1])
a.append(["hari","curry","ghari"])
a
# Out:
# ['dd', 21, 'das']
# 331
# 21
# [['dd', 21, 'das'], 331, '44', 'prick', ['hari', 'curry', 'ghari']]

# %%
a=[['dd', 21, 'das'], 331, '44', 'prick', ['hari', 'curry', 'ghari']]
del a[4][2]
del a[0]
a
# Out:
# [331, '44', 'prick', ['hari', 'curry']]

# %%
# wrong
a=[
   ['dari', 'prick'], 
    ['hari', 'curry']
   ]
name=input("Enter name : ")
    
for i in a:
    if name in i:
        print(name,"in list")
        break
    else:
        print(name,"not in list")
        break
# Out:
# curry not in list

# %%
table=list()
n=int(input("Enter no. of records : "))

for i in range(n):
    
    name=input("Enter name : ")
    age=int(input("Enter age : "))
    address=input("Enter address : ")
    
    table.append([name,age,address])
    
print(table)
# Out:
# [['abhilekh', 3, 'kharibot'], ['abihlekh', 44, 'chagal'], ['alisha', 41, 'chhetrapati']]

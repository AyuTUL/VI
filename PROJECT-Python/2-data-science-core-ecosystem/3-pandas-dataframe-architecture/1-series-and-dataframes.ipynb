# %% [markdown]
# # Data Science
# collection -> cleaning -> analyzing -> predicting -> making decision using data
#
# Example:\
# weather forecasting, banks detecting frauds, hospital predicting disease
#
# ### Scenario:
# want to predict student marks:
#
# - collect data (study hours, marks)
# - clean data
# - analyze patterns
# - train ML model
# - predict marks
# - show results in graph

# %%
import pandas as pd

# %%
df=pd.DataFrame({
    "Name":["Ram","Shyam","Hari"],
    "Marks":[90,90,90]
}
,index=[100,200,300])
df
# Out:
#       Name  Marks
# 100    Ram     90
# 200  Shyam     90
# 300   Hari     90

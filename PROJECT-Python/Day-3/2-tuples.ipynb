# %%
# tuple
# immutable
# defined by small bracket
a=(1,2,3,6)
print(a)
print(type(a))
print(a[3])

# %%
a=(1)
print(type(a))
b=(1,)
print(type(b))
print(len(b))

# %%
a="hello"
tuple(a)

# %%
# list inside tuple
a=([3,2],[3,5],[33])
a

# %%
# nested tuple
a=(21,(21,))
a
